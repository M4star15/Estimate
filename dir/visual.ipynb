# %%
# %run download_data.py
# Out:
# Fetched data for MMM
# Fetched data for AOS
# Fetched data for ABT
# Fetched data for ABBV
# Fetched data for ACN
# Fetched data for ADBE
# Fetched data for AMD
# Fetched data for AES
# Fetched data for AFL
# Fetched data for A
# Fetched data for APD
# Fetched data for ABNB
# Fetched data for AKAM
# Fetched data for ALB
# Fetched data for ARE
# Fetched data for ALGN
# Fetched data for ALLE
# Fetched data for LNT
# Fetched data for ALL
# Fetched data for GOOGL
# Fetched data for GOOG
# Fetched data for MO
# Fetched data for AMZN
# Fetched data for AMCR
# Fetched data for AEE
# Fetched data for AEP
# Fetched data for AXP
# Fetched data for AIG
# Fetched data for AMT
# Fetched data for AWK
# Fetched data for AMP
# Fetched data for AME
# Fetched data for AMGN
# Fetched data for APH
# Fetched data for ADI
# Fetched data for ANSS
# Fetched data for AON
# Fetched data for APA
# Fetched data for APO
# Fetched data for AAPL
# Fetched data for AMAT
# Fetched data for APTV
# ...

# %%
# %run analysis.py
# Out:
#   Stock Symbol             Company Name                         Industry  \
# 0          MMM               3M Company                    Conglomerates
# 1          AOS  A. O. Smith Corporation   Specialty Industrial Machinery
# 2          ABT      Abbott Laboratories                  Medical Devices
# 3         ABBV              AbbVie Inc.     Drug Manufacturers - General
# 4          ACN            Accenture plc  Information Technology Services
#
#      Market Cap  Revenue Growth    EPS  P/E Ratio  Return on Equity (ROE)  \
# 0  8.210733e+10           0.004   7.26  20.964186                 1.13294
# 1  9.758165e+09          -0.037   3.63  18.539946                 0.29544
# 2  2.218895e+11           0.049   7.64  16.744764                 0.14840
# 3  3.249770e+11           0.038   2.39  76.945600                 0.56407
# 4  2.407785e+11           0.026  11.93  32.267395                 0.26675
#
#    Debt-to-Equity Ratio  Operating Cash Flow  Free Cash Flow  \
# ...

# %%
# %run clean.py
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 413 entries, 0 to 502
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Stock Symbol            413 non-null    object
#  1   Company Name            413 non-null    object
#  2   Industry                413 non-null    object
#  3   Market Cap              413 non-null    float64
#  4   Revenue Growth          413 non-null    float64
#  5   EPS                     413 non-null    float64
#  6   P/E Ratio               413 non-null    float64
#  7   Return on Equity (ROE)  413 non-null    float64
#  8   Debt-to-Equity Ratio    413 non-null    float64
#  9   Operating Cash Flow     413 non-null    float64
#  10  Free Cash Flow          413 non-null    float64
#  11  Latest Close Price      413 non-null    float64
# dtypes: float64(9), object(3)
# memory usage: 41.9+ KB
# None
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("all_stock_data.csv")
print(df[df["Stock Symbol"] == "NVR"])
# Out:
#     Stock Symbol Company Name                  Industry    Market Cap  \
# 349          NVR    NVR, Inc.  Residential Construction  2.491966e+10
#
#      Revenue Growth     EPS  P/E Ratio  Return on Equity (ROE)  \
# 349            0.06  506.62  15.822866                 0.38716
#
#      Debt-to-Equity Ratio  Operating Cash Flow  Free Cash Flow  \
# 349                24.537         1.233118e+09    1.009651e+09
#
#      Latest Close Price
# 349         8016.180176
